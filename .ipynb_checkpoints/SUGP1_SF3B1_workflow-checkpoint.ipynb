# %%
import subprocess
from datetime import datetime

# %%
today_date = datetime.now().strftime("%m.%d.%Y")

# %%
# !python3 alignment.py --star-path "/private/groups/brookslab/bin/STAR-2.7.10a/bin/Linux_x86_64/STAR" \
--genomeDir "/private/groups/brookslab/reference_indices/star_hg38_rausharm" \
--readFilesIn "/private/groups/brookslab/scratch/rausharm/sra_acc.02.09.24/fastq/SRR12801019_pass_1.fastq" "/private/groups/brookslab/scratch/rausharm/sra_acc.02.09.24/fastq/SRR12801019_pass_2.fastq" \
--output-dir "/private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/" \
--metadata "SF3B1" \
--condition "Reference" \
--paired
# Out:
# INFO:root:Running STAR alignment for SRR12801019 with command: /private/groups/brookslab/bin/STAR-2.7.10a/bin/Linux_x86_64/STAR --runThreadN 10 --genomeDir /private/groups/brookslab/reference_indices/star_hg38_rausharm --readFilesIn /private/groups/brookslab/scratch/rausharm/sra_acc.02.09.24/fastq/SRR12801019_pass_1.fastq /private/groups/brookslab/scratch/rausharm/sra_acc.02.09.24/fastq/SRR12801019_pass_2.fastq --outFileNamePrefix /private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/SRR12801019/SRR12801019_ --outSAMtype BAM SortedByCoordinate
# ...

# %%
# !python3 alignment.py --star-path "/private/groups/brookslab/bin/STAR-2.7.10a/bin/Linux_x86_64/STAR" \
--genomeDir "/private/groups/brookslab/reference_indices/star_hg38_rausharm" \
--readFilesIn "/private/groups/brookslab/scratch/rausharm/sra_acc.02.09.24/fastq/SRR12801023_pass_1.fastq" "/private/groups/brookslab/scratch/rausharm/sra_acc.02.09.24/fastq/SRR12801023_pass_2.fastq" \
--output-dir "/private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/" \
--metadata "SF3B1" \
--condition "Reference" \
--paired
# Out:
# INFO:root:Running STAR alignment for SRR12801023 with command: /private/groups/brookslab/bin/STAR-2.7.10a/bin/Linux_x86_64/STAR --runThreadN 10 --genomeDir /private/groups/brookslab/reference_indices/star_hg38_rausharm --readFilesIn /private/groups/brookslab/scratch/rausharm/sra_acc.02.09.24/fastq/SRR12801023_pass_1.fastq /private/groups/brookslab/scratch/rausharm/sra_acc.02.09.24/fastq/SRR12801023_pass_2.fastq --outFileNamePrefix /private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/SRR12801023/SRR12801023_ --outSAMtype BAM SortedByCoordinate
# ...

# %%
# !python3 alignment.py --star-path "/private/groups/brookslab/bin/STAR-2.7.10a/bin/Linux_x86_64/STAR" \
--genomeDir "/private/groups/brookslab/reference_indices/star_hg38_rausharm" \
--readFilesIn "/private/groups/brookslab/scratch/rausharm/sra_acc.02.09.24/fastq/SRR12801020_pass_1.fastq" "/private/groups/brookslab/scratch/rausharm/sra_acc.02.09.24/fastq/SRR12801020_pass_2.fastq" \
--output-dir "/private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/" \
--metadata "SUGP1" \
--condition "Sample" \
--paired
# Out:
# INFO:root:Running STAR alignment for SRR12801020 with command: /private/groups/brookslab/bin/STAR-2.7.10a/bin/Linux_x86_64/STAR --runThreadN 10 --genomeDir /private/groups/brookslab/reference_indices/star_hg38_rausharm --readFilesIn /private/groups/brookslab/scratch/rausharm/sra_acc.02.09.24/fastq/SRR12801020_pass_1.fastq /private/groups/brookslab/scratch/rausharm/sra_acc.02.09.24/fastq/SRR12801020_pass_2.fastq --outFileNamePrefix /private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/SRR12801020/SRR12801020_ --outSAMtype BAM SortedByCoordinate
# ...

# %%
# !python3 alignment.py --star-path "/private/groups/brookslab/bin/STAR-2.7.10a/bin/Linux_x86_64/STAR" \
--genomeDir "/private/groups/brookslab/reference_indices/star_hg38_rausharm" \
--readFilesIn "/private/groups/brookslab/scratch/rausharm/sra_acc.02.09.24/fastq/SRR12801024_pass_1.fastq" "/private/groups/brookslab/scratch/rausharm/sra_acc.02.09.24/fastq/SRR12801024_pass_2.fastq" \
--output-dir "/private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/" \
--metadata "SUGP1" \
--condition "Sample" \
--paired
# Out:
# INFO:root:Running STAR alignment for SRR12801024 with command: /private/groups/brookslab/bin/STAR-2.7.10a/bin/Linux_x86_64/STAR --runThreadN 10 --genomeDir /private/groups/brookslab/reference_indices/star_hg38_rausharm --readFilesIn /private/groups/brookslab/scratch/rausharm/sra_acc.02.09.24/fastq/SRR12801024_pass_1.fastq /private/groups/brookslab/scratch/rausharm/sra_acc.02.09.24/fastq/SRR12801024_pass_2.fastq --outFileNamePrefix /private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/SRR12801024/SRR12801024_ --outSAMtype BAM SortedByCoordinate
# ...

# %%
# !python3 bam_qc_samtools.py "/private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24"
# Out:
# INFO:root:Running samtools flagstat on /private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/SRR12801019/SRR12801019_Aligned.sortedByCoord.out.bam
# INFO:root:Running samtools stats on /private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/SRR12801019/SRR12801019_Aligned.sortedByCoord.out.bam
# INFO:root:Running samtools flagstat on /private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/SRR12801020/SRR12801020_Aligned.sortedByCoord.out.bam
# INFO:root:Running samtools stats on /private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/SRR12801020/SRR12801020_Aligned.sortedByCoord.out.bam
# INFO:root:Running samtools flagstat on /private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/SRR12801023/SRR12801023_Aligned.sortedByCoord.out.bam
# INFO:root:Running samtools stats on /private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/SRR12801023/SRR12801023_Aligned.sortedByCoord.out.bam
# ...

# %%
# !python3 differential_splicing.py \
--genome "/private/groups/brookslab/reference_sequence/GRCh38.p13.genome.fa" \
--manifest "/private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/bam_manifest.txt" \
--annotations "/private/groups/brookslab/reference_annotations/gencode.v37.annotation.gtf" \
--output-prefix "/private/groups/brookslab/rausharm/RBPSig/03.11.24"
# Out:
# Finding junctions from 4 BAM files...
# bam: /private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/SRR12801019/SRR12801019_Aligned.sortedByCoord.out.bam
# number of junctions found: 517327
# saved to bed: /private/groups/brookslab/rausharm/RBPSig/03.11.24_junction_beds/SRR12801019_Aligned.sortedByCoord.out.junc.bed
# bam: /private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/SRR12801023/SRR12801023_Aligned.sortedByCoord.out.bam
# number of junctions found: 523173
# saved to bed: /private/groups/brookslab/rausharm/RBPSig/03.11.24_junction_beds/SRR12801023_Aligned.sortedByCoord.out.junc.bed
# bam: /private/groups/brookslab/rausharm/RBPSig/star_output_03.11.24/SRR12801020/SRR12801020_Aligned.sortedByCoord.out.bam
# number of junctions found: 576971
# saved to bed: /private/groups/brookslab/rausharm/RBPSig/03.11.24_junction_beds/SRR12801020_Aligned.sortedByCoord.out.junc.bed
# ...

# %%
# !python3 filter_data.py --output-prefix "/private/groups/brookslab/rausharm/RBPSig/03.11.24"
# Out:
# Filtered data saved to /private/groups/brookslab/rausharm/RBPSig/03.11.24_filteredPairwiseResults.tsv
# Filtered _allPS data saved to /private/groups/brookslab/rausharm/RBPSig/03.11.24_filteredAllPS.tsv

# %% [markdown]
# !python3 /private/groups/brookslab/rausharm/splicedice/code/signature.py compare \
# -p /private/groups/brookslab/rausharm/RBPSig/03.11.24_allPS.tsv \
# -m /private/groups/brookslab/rausharm/RBPSig/manifest.txt \
# -o /private/groups/brookslab/rausharm/RBPSig/splicedice_compare

# %%
# !python3 /private/groups/brookslab/rausharm/splicedice/code/signature.py fit_beta \
-x significance_threshold=1 \
-p /private/groups/brookslab/rausharm/RBPSig/03.11.24_allPS.tsv \
-n 10 \
-m /private/groups/brookslab/rausharm/RBPSig/manifest.txt \
-o test
# Out:
# significance_threshold=0.05
# try
# Testing for differential splicing...
# Groups: Reference (2), Sample (2)
# ('chr1:14829-14969:-', [1.0, 1.0, 1.0, 1.0])
# ('chr1:15038-15795:+', [1.0, 1.0, 1.0, 1.0])
# ('chr1:15038-15795:-', [1.0, 1.0, 1.0, 1.0])
# ('chr1:15947-16606:+', [1.0, 1.0, 1.0, 1.0])
# ('chr1:15947-16606:-', [1.0, 1.0, 1.0, 1.0])
# ('chr1:16765-16857:+', [1.0, 1.0, 1.0, 1.0])
# ('chr1:16765-16857:-', [1.0, 1.0, 1.0, 1.0])
# ('chr1:17055-17232:+', [0.969, 0.978, 0.975, 0.947])
# ('chr1:17055-17232:-', [0.927, 0.973, 0.962, 0.964])
# ('chr1:17055-17605:+', [0.022, 0.016, 0.018, 0.04])
# Process Process-2:
# Traceback (most recent call last):
#   File "/private/home/rausharm/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/private/home/rausharm/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# ...
